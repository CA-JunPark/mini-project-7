# %%
import

# %% [markdown]
# ## Dataset: Blood Cell Detection

# %% [markdown]
# ## Get COCO weights (yolo26n.pt or yolo26s.pt)

# %% [markdown]
# ## Train for a minimum of 25 epochs

# %% [markdown]
# ## Evaluate with mAP@50, mAP@50-95, precision, and recall

# %% [markdown]
# ## Show per-class metrics and confusion matrix

# %% [markdown]
# ## Visualize at least 6 prediction examples on validation images

# %% [markdown]
# ## Training Curves (loss and mAP over epochs)

# %% [markdown]
# ## Analysis
